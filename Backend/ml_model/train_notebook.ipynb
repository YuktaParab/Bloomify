# %% [markdown]
# # Space Photo Analysis Model Training
# Train a model to analyze space photos for plant recommendations

# %%
# Import the training script
import sys
sys.path.append('.')
from train_space_model import *

# %%
# Run the main training pipeline
main()

# %% [markdown]
# ## Test Predictions

# %%
from predict import SpaceAnalyzer

# Load trained model
analyzer = SpaceAnalyzer()

# Test on an image
result = analyzer.predict('data/test_image.jpg')
print(json.dumps(result, indent=2))
